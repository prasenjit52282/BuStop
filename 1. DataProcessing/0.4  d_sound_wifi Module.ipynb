# %% [markdown]
# # Analysis_d.csv Generator.csv

# %%
from libraries.dHelper import *
from libraries.wifiGrouper import *
from libraries.soundGrouper import *
from libraries.utils import *
import glob

# %%
# ouput parent directory of Copy Module for e.g. : '.\Trails'
base_folder_address = "./Trails" 

folder_pattern = "\**\**" # '\**\' is for recursive folders
processed_gps_filename = 'Analysis_GPS.csv'

directories = glob.glob(base_folder_address+folder_pattern)

d = 20 # in meters
sound_threshold = 70 # in decibels. Keep same value as in soundModule.ipynb

# %% [markdown]
# #Processing

# %%
for directory in directories:
    print(f"--------- For directory {directory} ----------")
    # Empty df
    d_df = pd.DataFrame()
    try:
        # Load Analysis_GPS
        gps = os.path.join(directory, processed_gps_filename)
        gps_df = pd.read_csv(gps)
        gps_df['start_time'] = gps_df['start_time'].apply(lambda x: time_as_int(x))
        gps_df['end_time'] = gps_df['end_time'].apply(lambda x: time_as_int(x))
        try:
            gps_raw = glob.glob(directory+os.path.sep+'\GPS.csv')[0]
            # For changing start time for d
            print(f"Increasing start_time for d...")
            gps_df = increase_d(d, gps_raw, gps_df)
            gps_df['start_time'] = gps_df['d_start_time']
            gps_df = gps_df[['start_time', 'end_time']]

            # For WiFi with d
            print(f"Processing WiFi for d = {d}...")
            try:
                wifi = glob.glob(directory+os.path.sep+'\*WiFi*.txt')[0]
                wifi_df = process_wifi(wifi, gps_df)
                wifi_df = wifi_df[['wifi_count', 'edge_wifi_count']]
                d_df['d_wifi_count'] = wifi_df['wifi_count']
                d_df['d_edge_wifi_count'] = wifi_df['edge_wifi_count']
            except IndexError: # Missing WiFi file
                print(f"{directory} missing WiFi file. Filling with NaN")
                wifi_df = make_blank_wifi_df(len(gps_df.index))
                d_df['d_wifi_count'] = wifi_df['wifi_count']
                d_df['d_edge_wifi_count'] = wifi_df['edge_wifi_count']
            finally:
                print("Processed WiFi.")
            
            # For sound with d
            print(f"Processing Sound for d = {d}...")
            try:
                sound = glob.glob(directory+os.path.sep+'\*SOUND*.wav')[0]
                sound_df = process_sound(sound, gps_df, sound_threshold)
                sound_df = sound_df[['honk_duration', 'edge_honk_duration']]
                d_df['d_honk_duration'] = sound_df['honk_duration']
                d_df['d_edge_honk_duration'] = sound_df['edge_honk_duration']
            except IndexError: # Missing Sound file
                print(f"{directory} missing Sound file. Filling with NaN")
                sound_df = make_blank_sound_df(len(gps_df.index))
                d_df['d_honk_duration'] = sound_df['honk_duration']
                d_df['d_edge_honk_duration'] = sound_df['edge_honk_duration']
            finally:
                print("Processed Sound.")
            
            # Saving d analysis.
            print(f"Saving analysis for d = {d}...")
            save_df(d_df, directory, 'd-analysis')
            d_df = None
            
        except IndexError:
            print("Raw GPS i.e. GPS.csv not found.")
        except Exception as e:
            raise e
    except FileNotFoundError:
        print(f"Processed GPS i.e. {processed_gps_filename} not found.")
    except Exception as e:
        raise e
    finally:
        print("---------- XXXXXXXXXX ----------")
    
print("Completed")
# Out:
# --------- For directory ./Trails\down\01-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\01-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\01-07-2019_DATA_17_03_44 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\01-07-2019_DATA_17_03_44\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\02-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\02-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\02-07-2019_DATA_09_52_39 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\02-07-2019_DATA_09_52_39\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\02-07-2019_DATA_11_11_23 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\02-07-2019_DATA_11_11_23\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\02-07-2019_DATA_12_06_05 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\02-07-2019_DATA_12_06_05\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\03-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\03-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\03-07-2019_DATA_09_56_40 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\03-07-2019_DATA_09_56_40\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\03-07-2019_DATA_11_52_11 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\03-07-2019_DATA_11_52_11\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\03-07-2019_DATA_18_04_00 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\03-07-2019_DATA_18_04_00\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\03-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\03-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\03-09-2019_DATA_18_38_56 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\03-09-2019_DATA_18_38_56\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\04-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\04-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\04-07-2019_DATA_19_23_45 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\04-07-2019_DATA_19_23_45\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\04-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\04-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\04-09-2019_DATA_18_29_36 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\04-09-2019_DATA_18_29_36\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\05-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\05-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\05-07-2019_DATA_09_21_15 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\05-07-2019_DATA_09_21_15\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\05-07-2019_DATA_10_56_28 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\05-07-2019_DATA_10_56_28\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\05-07-2019_DATA_11_49_44 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\05-07-2019_DATA_11_49_44\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\05-07-2019_DATA_17_01_55 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\05-07-2019_DATA_17_01_55\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\05-07-2019_DATA_18_56_42 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\05-07-2019_DATA_18_56_42\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\05-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\05-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\06-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\06-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\06-07-2019_DATA_09_23_17 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\06-07-2019_DATA_09_23_17\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\06-07-2019_DATA_09_48_06 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\06-07-2019_DATA_09_48_06\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\06-07-2019_DATA_10_58_09 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\06-07-2019_DATA_10_58_09\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\06-07-2019_DATA_11_51_02 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\06-07-2019_DATA_11_51_02\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\06-07-2019_DATA_18_03_58 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\06-07-2019_DATA_18_03_58\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\12-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\12-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\13-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\13-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\13-09-2019_DATA_14_17_30 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\13-09-2019_DATA_14_17_30\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\13-09-2019_DATA_17_29_15 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\13-09-2019_DATA_17_29_15\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\14-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\14-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\14-09-2019_DATA_16_39_11 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\14-09-2019_DATA_16_39_11\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\15-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\15-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\15-09-2019_DATA_18_22_14 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\15-09-2019_DATA_18_22_14\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\16-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\16-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\16-09-2019_DATA_16_44_26 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\16-09-2019_DATA_16_44_26\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\16-09-2019_DATA_18_35_49 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\16-09-2019_DATA_18_35_49\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\17-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\17-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\17-09-2019_DATA_15_52_39 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\17-09-2019_DATA_15_52_39\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\17-09-2019_DATA_17_52_13 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\17-09-2019_DATA_17_52_13\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\20-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\20-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\20-09-2019_DATA_18_33_50 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\20-09-2019_DATA_18_33_50\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\21-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\21-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\21-09-2019_DATA_16_42_58 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\21-09-2019_DATA_16_42_58\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\21-09-2019_DATA_18_38_04 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\21-09-2019_DATA_18_38_04\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\23-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\23-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\23-09-2019_DATA_16_00_03 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\23-09-2019_DATA_16_00_03\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\23-09-2019_DATA_18_05_16 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\23-09-2019_DATA_18_05_16\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\down\30-06-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\down\30-06-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\01-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\01-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\01-07-2019_DATA_15_59_01 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\01-07-2019_DATA_15_59_01\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\02-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\02-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\02-07-2019_DATA_08_59_55 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\02-07-2019_DATA_08_59_55\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\02-07-2019_DATA_10_58_35 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\02-07-2019_DATA_10_58_35\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\03-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\03-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\03-07-2019_DATA_08_46_57 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\03-07-2019_DATA_08_46_57\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\03-07-2019_DATA_10_58_15 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\03-07-2019_DATA_10_58_15\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\03-07-2019_DATA_17_00_17 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\03-07-2019_DATA_17_00_17\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\03-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\03-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\04-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\04-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\04-07-2019_DATA_18_39_02 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\04-07-2019_DATA_18_39_02\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\04-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\04-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\04-09-2019_DATA_17_21_38 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\04-09-2019_DATA_17_21_38\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\05-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\05-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\05-07-2019_DATA_08_28_46 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\05-07-2019_DATA_08_28_46\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\05-07-2019_DATA_10_09_30 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\05-07-2019_DATA_10_09_30\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\05-07-2019_DATA_10_46_37 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\05-07-2019_DATA_10_46_37\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\05-07-2019_DATA_16_16_42 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\05-07-2019_DATA_16_16_42\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\05-07-2019_DATA_18_03_49 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\05-07-2019_DATA_18_03_49\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\05-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\05-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\06-07-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\06-07-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\06-07-2019_DATA_08_40_03 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\06-07-2019_DATA_08_40_03\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\06-07-2019_DATA_08_57_09 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\06-07-2019_DATA_08_57_09\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\06-07-2019_DATA_10_07_40 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\06-07-2019_DATA_10_07_40\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\06-07-2019_DATA_11_00_08 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\06-07-2019_DATA_11_00_08\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\06-07-2019_DATA_16_58_00 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\06-07-2019_DATA_16_58_00\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\12-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\12-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\13-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\13-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\13-09-2019_DATA_12_58_59 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\13-09-2019_DATA_12_58_59\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\13-09-2019_DATA_16_29_45 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\13-09-2019_DATA_16_29_45\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\14-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\14-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\14-09-2019_DATA_15_40_40 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\14-09-2019_DATA_15_40_40\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\15-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\15-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\15-09-2019_DATA_17_25_36 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\15-09-2019_DATA_17_25_36\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\16-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\16-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\16-09-2019_DATA_15_39_29 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\16-09-2019_DATA_15_39_29\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\16-09-2019_DATA_17_40_21 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\16-09-2019_DATA_17_40_21\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\17-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\17-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\17-09-2019_DATA_14_57_00 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\17-09-2019_DATA_14_57_00\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\17-09-2019_DATA_16_45_23 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\17-09-2019_DATA_16_45_23\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\20-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\20-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\20-09-2019_DATA_17_32_37 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\20-09-2019_DATA_17_32_37\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\21-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\21-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\21-09-2019_DATA_15_38_33 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\21-09-2019_DATA_15_38_33\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\21-09-2019_DATA_17_38_40 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\21-09-2019_DATA_17_38_40\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\23-09-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\23-09-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\23-09-2019_DATA_14_56_21 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\23-09-2019_DATA_14_56_21\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\23-09-2019_DATA_16_55_35 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\23-09-2019_DATA_16_55_35\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# --------- For directory ./Trails\up\28-06-2019 ----------
# Increasing start_time for d...
# Processing WiFi for d = 20...
# Processed WiFi.
# Processing Sound for d = 20...
# Processed Sound.
# Saving analysis for d = 20...
# Saved in: ./Trails\up\28-06-2019\Analysis_d.csv
# ---------- XXXXXXXXXX ----------
# Completed

# %%
#NICE
