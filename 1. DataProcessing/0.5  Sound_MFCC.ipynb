# %% [markdown]
# # Sound_MFCC.csv Generator

# %%
import os
import glob
import librosa
import datetime as d
import pandas as pd
import numpy as np
from scipy.io import wavfile as wav

# %%
#Helper functions...

def read_audio(filename):
    sr, _ = wav.read(filename)
    x, sr = librosa.load(filename,sr=sr)
    
    _,_,year,month,day,hour,minute,sec,_=filename.split("\\")[-1].split('_')
    start_time=d.datetime(int(year),int(month),int(day),int(hour),int(minute),int(sec))
    
    time_data=[]
    d_counter=0
    x_len=x.shape[0]

    for i in range(x_len):
        if (i+1)%sr==0:
            time_data.extend([str(start_time)]*sr)
            d_counter+=sr
            start_time+=d.timedelta(seconds=1)
    else:
        remaining=x_len-d_counter
        time_data.extend([str(start_time)]*remaining)
        
    df=pd.DataFrame({'time':time_data,'value':x})
    
    return df,sr


def format_date(mmddyyyy):
    mm,dd,yyyy=mmddyyyy.split('/')
    return '-'.join([yyyy,mm,dd])


def do_mfcc(start_to_end):
    start,end=start_to_end.split('->')
    slot=df_wav[(df_wav.time>=start) & (df_wav.time<=end)].value.values
    mfccs = librosa.feature.mfcc(slot, sr=sr)
    return sorted(list(mfccs.mean(axis=1)),reverse=True)[:MFCC_COMPONENT]

# %%
#Hyper-Parameters...

MFCC_COMPONENT=5
folders=glob.glob("./Trails/*/*/")
num_folders=len(folders)

# %% [markdown]
# folder=folders[0]
# df_wav=read_audio(glob.glob(folder+'*.wav')[0])
# df_ana_gps=pd.read_csv(glob.glob(folder+'Analysis_GPS.csv')[0])
#
# df_time_slots=\
# pd.DataFrame(df_ana_gps.start_date.apply(format_date)+' '+\
# df_ana_gps.start_time+'->'+\
# df_ana_gps.end_date.apply(format_date)+' '+\
# df_ana_gps.end_time,columns=['time_slots'])
#
# res=df_time_slots.time_slots.apply(do_mfcc)
# df_mfcc=pd.DataFrame(list(res),columns=[f'mfcc{i}' for i in range(MFCC_COMPONENT)])
# df_mfcc.head()

# %%
#Processing....

for i,folder in enumerate(folders):
    if os.path.isfile(folder+'Sound_MFCC.csv'): #checking weither Sound_MFCC file exist already?
        print(f'{i+1}/{num_folders}. folder: {folder} is already processed and Augumented\n') #file is already processed
    else:
        df_wav,sr=read_audio(glob.glob(folder+'*.wav')[0])
        df_ana_gps=pd.read_csv(folder+'Analysis_GPS.csv')
        
        df_time_slots=\
                pd.DataFrame(df_ana_gps.start_date.apply(format_date)+' '+\
                df_ana_gps.start_time+'->'+\
                df_ana_gps.end_date.apply(format_date)+' '+\
                df_ana_gps.end_time,columns=['time_slots'])
        
        res=df_time_slots.time_slots.apply(do_mfcc)
        
        df_mfcc=pd.DataFrame(list(res),columns=[f'mfcc{i}' for i in range(MFCC_COMPONENT)])
        df_mfcc.to_csv(folder+'Sound_MFCC.csv',index=False)

        print(f'{i+1}/{num_folders}. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: {folder}\n')
        
print('Completed.')
# Out:
# 1/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\01-07-2019\
#
# 2/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\01-07-2019_DATA_17_03_44\
#
# 3/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\02-07-2019\
#
# 4/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\02-07-2019_DATA_09_52_39\
#
# 5/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\02-07-2019_DATA_11_11_23\
#
# 6/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\02-07-2019_DATA_12_06_05\
#
# 7/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\03-07-2019\
#
# 8/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\03-07-2019_DATA_09_56_40\
#
# 9/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\03-07-2019_DATA_11_52_11\
#
# 10/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\03-07-2019_DATA_18_04_00\
#
# 11/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\03-09-2019\
#
# 12/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\03-09-2019_DATA_18_38_56\
#
# 13/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\04-07-2019\
#
# 14/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\04-07-2019_DATA_19_23_45\
#
# 15/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\04-09-2019\
#
# 16/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\04-09-2019_DATA_18_29_36\
#
# 17/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\05-07-2019\
#
# 18/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\05-07-2019_DATA_09_21_15\
#
# 19/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\05-07-2019_DATA_10_56_28\
#
# 20/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\05-07-2019_DATA_11_49_44\
#
# 21/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\05-07-2019_DATA_17_01_55\
#
# 22/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\05-07-2019_DATA_18_56_42\
#
# 23/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\05-09-2019\
#
# 24/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\06-07-2019\
#
# 25/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\06-07-2019_DATA_09_23_17\
#
# 26/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\06-07-2019_DATA_09_48_06\
#
# 27/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\06-07-2019_DATA_10_58_09\
#
# 28/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\06-07-2019_DATA_11_51_02\
#
# 29/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\06-07-2019_DATA_18_03_58\
#
# 30/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\12-09-2019\
#
# 31/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\13-09-2019\
#
# 32/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\13-09-2019_DATA_14_17_30\
#
# 33/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\13-09-2019_DATA_17_29_15\
#
# 34/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\14-09-2019\
#
# 35/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\14-09-2019_DATA_16_39_11\
#
# 36/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\15-09-2019\
#
# 37/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\15-09-2019_DATA_18_22_14\
#
# 38/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\16-09-2019\
#
# 39/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\16-09-2019_DATA_16_44_26\
#
# 40/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\16-09-2019_DATA_18_35_49\
#
# 41/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\17-09-2019\
#
# 42/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\17-09-2019_DATA_15_52_39\
#
# 43/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\17-09-2019_DATA_17_52_13\
#
# 44/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\20-09-2019\
#
# 45/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\20-09-2019_DATA_18_33_50\
#
# 46/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\21-09-2019\
#
# 47/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\21-09-2019_DATA_16_42_58\
#
# 48/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\21-09-2019_DATA_18_38_04\
#
# 49/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\23-09-2019\
#
# 50/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\23-09-2019_DATA_16_00_03\
#
# 51/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\23-09-2019_DATA_18_05_16\
#
# 52/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\down\30-06-2019\
#
# 53/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\01-07-2019\
#
# 54/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\01-07-2019_DATA_15_59_01\
#
# 55/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\02-07-2019\
#
# 56/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\02-07-2019_DATA_08_59_55\
#
# 57/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\02-07-2019_DATA_10_58_35\
#
# 58/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\03-07-2019\
#
# 59/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\03-07-2019_DATA_08_46_57\
#
# 60/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\03-07-2019_DATA_10_58_15\
#
# 61/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\03-07-2019_DATA_17_00_17\
#
# 62/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\03-09-2019\
#
# 63/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\04-07-2019\
#
# 64/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\04-07-2019_DATA_18_39_02\
#
# 65/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\04-09-2019\
#
# 66/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\04-09-2019_DATA_17_21_38\
#
# 67/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\05-07-2019\
#
# 68/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\05-07-2019_DATA_08_28_46\
#
# 69/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\05-07-2019_DATA_10_09_30\
#
# 70/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\05-07-2019_DATA_10_46_37\
#
# 71/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\05-07-2019_DATA_16_16_42\
#
# 72/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\05-07-2019_DATA_18_03_49\
# 73/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\05-09-2019\
#
# 74/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\06-07-2019\
#
# 75/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\06-07-2019_DATA_08_40_03\
#
# 76/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\06-07-2019_DATA_08_57_09\
#
# 77/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\06-07-2019_DATA_10_07_40\
#
# 78/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\06-07-2019_DATA_11_00_08\
#
# 79/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\06-07-2019_DATA_16_58_00\
#
# 80/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\12-09-2019\
#
# 81/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\13-09-2019\
#
# 82/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\13-09-2019_DATA_12_58_59\
#
# 83/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\13-09-2019_DATA_16_29_45\
#
# 84/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\14-09-2019\
#
# 85/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\14-09-2019_DATA_15_40_40\
#
# 86/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\15-09-2019\
#
# 87/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\15-09-2019_DATA_17_25_36\
#
# 88/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\16-09-2019\
#
# 89/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\16-09-2019_DATA_15_39_29\
#
# 90/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\16-09-2019_DATA_17_40_21\
#
# 91/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\17-09-2019\
#
# 92/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\17-09-2019_DATA_14_57_00\
#
# 93/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\17-09-2019_DATA_16_45_23\
#
# 94/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\20-09-2019\
#
# 95/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\20-09-2019_DATA_17_32_37\
#
# 96/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\21-09-2019\
#
# 97/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\21-09-2019_DATA_15_38_33\
#
# 98/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\21-09-2019_DATA_17_38_40\
#
# 99/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\23-09-2019\
#
# 100/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\23-09-2019_DATA_14_56_21\
#
# 101/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\23-09-2019_DATA_16_55_35\
#
# 102/102. Processed "Analysis_GPS.csv" and added file "Sound_MFCC.csv" in folder: ./Trails\up\28-06-2019\
#
# Completed.

# %%
#NICE
